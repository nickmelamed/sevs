# %% [markdown]
# # Consistency Probes
#
# Starter notebook. Add code as you implement real data/models.

# %%
# !python -m sevs.cli smoke-test --config ../configs/eval/eval_default.yaml
